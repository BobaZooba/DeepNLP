# %%
import numpy as np

from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report

import torch
from torch.utils.data import DataLoader
from torchvision.datasets import MNIST
from torchvision import transforms

import matplotlib.pyplot as plt

from tqdm import tqdm

import time

# %% [markdown]
# # Это все заработает со сделанной домашкой

# %% [markdown]
# # Import our library

# %%
from our_library import layers, wrapper, tools

# %% [markdown]
# # Never mind, just data normalization with magic ImageNet numbers

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))
])

# %% [markdown]
# # Load MNIST

# %%
train_dataset = MNIST('.', train=True, download=True, transform=transform)
test_dataset = MNIST('.', train=False, transform=transform)

# %% [markdown]
# # 2 classes MNIST

# %%
train_dataset.data = train_dataset.data[(train_dataset.targets == 3) | (train_dataset.targets == 7)]
train_dataset.targets = train_dataset.targets[(train_dataset.targets == 3) | (train_dataset.targets == 7)]

test_dataset.data = test_dataset.data[(test_dataset.targets == 3) | (test_dataset.targets == 7)]
test_dataset.targets = test_dataset.targets[(test_dataset.targets == 3) | (test_dataset.targets == 7)]

train_dataset.targets = (train_dataset.targets == 7).long()
test_dataset.targets = (test_dataset.targets == 7).long()

# %% [markdown]
# # Data loader for batches and efficient loading

# %%
train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=128, shuffle=False)

# %% [markdown]
# # Show data

# %%
X, y = next(iter(train_loader))
X = X.numpy()
y = y.numpy()

plt.figure(figsize=(6, 7))
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.imshow(X[i].reshape(28, 28), cmap=plt.cm.Greys_r)
    plt.title(y[i])
    plt.axis('off')

# %% [markdown]
# # Our Neural Network

# %%
neural_network = layers.NeuralNetwork([layers.Linear(784, 100),
                                       layers.Sigmoid(),
                                       layers.Linear(100, 100),
                                       layers.Sigmoid(),
                                       layers.Linear(100, 1),
                                       layers.Sigmoid()])

loss = layers.BCELoss()

# %% [markdown]
# # Train

# %%
classifier = wrapper.MNISTWrapper(model=neural_network,
                                  loss=loss,
                                  learning_rate=0.05)

# %%
classifier.train(train_loader, test_loader)
# Out:
# Epoch 1: 100%|██████████| 12396/12396 [00:02<00:00, 5737.37it/s, loss=0.694, metric=0.507]
# Epoch 2: 100%|██████████| 12396/12396 [00:02<00:00, 5967.98it/s, loss=0.694, metric=0.507]
# Epoch 3: 100%|██████████| 12396/12396 [00:02<00:00, 6108.62it/s, loss=0.694, metric=0.503]
# Epoch 4: 100%|██████████| 12396/12396 [00:02<00:00, 6081.62it/s, loss=0.694, metric=0.505]
# Epoch 5: 100%|██████████| 12396/12396 [00:02<00:00, 6104.86it/s, loss=0.694, metric=0.501]
# Epoch 6: 100%|██████████| 12396/12396 [00:02<00:00, 6144.81it/s, loss=0.693, metric=0.506]
# Epoch 7: 100%|██████████| 12396/12396 [00:02<00:00, 5593.70it/s, loss=0.693, metric=0.508]
# Epoch 8: 100%|██████████| 12396/12396 [00:03<00:00, 3793.92it/s, loss=0.692, metric=0.519]
# Epoch 9: 100%|██████████| 12396/12396 [00:02<00:00, 6575.75it/s, loss=0.691, metric=0.519]
# Epoch 10: 100%|██████████| 12396/12396 [00:02<00:00, 5928.42it/s, loss=0.687, metric=0.55]
# Epoch 11: 100%|██████████| 12396/12396 [00:02<00:00, 5685.45it/s, loss=0.678, metric=0.646]
# Epoch 12: 100%|██████████| 12396/12396 [00:02<00:00, 5867.95it/s, loss=0.637, metric=0.796]
# Epoch 13: 100%|██████████| 12396/12396 [00:02<00:00, 5724.73it/s, loss=0.474, metric=0.94]
# Epoch 14: 100%|██████████| 12396/12396 [00:02<00:00, 5576.01it/s, loss=0.244, metric=0.965]
# Epoch 15: 100%|██████████| 12396/12396 [00:02<00:00, 5629.21it/s, loss=0.143, metric=0.972]

# %%
classifier.plot()

# %% [markdown]
# # Use ReLU

# %%
neural_network = layers.NeuralNetwork([layers.Linear(784, 100),
                                       layers.ReLU(), 
                                       layers.Linear(100, 100),
                                       layers.ReLU(),
                                       layers.Linear(100, 1),
                                       layers.Sigmoid()])

loss = layers.BCELoss()

# %% [markdown]
# # Smaller learning rate

# %%
classifier = wrapper.MNISTWrapper(model=neural_network, 
                                  loss=loss,
                                  learning_rate=0.01)

# %%
classifier.train(train_loader, test_loader)
# Out:
# Epoch 1: 100%|██████████| 12396/12396 [00:01<00:00, 6500.37it/s, loss=0.682, metric=0.621]
# Epoch 2: 100%|██████████| 12396/12396 [00:02<00:00, 5471.62it/s, loss=0.611, metric=0.749]
# Epoch 3: 100%|██████████| 12396/12396 [00:02<00:00, 5298.58it/s, loss=0.495, metric=0.858]
# Epoch 4: 100%|██████████| 12396/12396 [00:02<00:00, 5519.45it/s, loss=0.406, metric=0.911]
# Epoch 5: 100%|██████████| 12396/12396 [00:02<00:00, 5530.67it/s, loss=0.347, metric=0.935]
# Epoch 6: 100%|██████████| 12396/12396 [00:02<00:00, 5724.46it/s, loss=0.305, metric=0.947]
# Epoch 7: 100%|██████████| 12396/12396 [00:02<00:00, 5413.73it/s, loss=0.273, metric=0.955]
# Epoch 8: 100%|██████████| 12396/12396 [00:02<00:00, 5710.09it/s, loss=0.247, metric=0.96]
# Epoch 9: 100%|██████████| 12396/12396 [00:02<00:00, 5811.23it/s, loss=0.225, metric=0.964]
# Epoch 10: 100%|██████████| 12396/12396 [00:02<00:00, 5731.57it/s, loss=0.207, metric=0.967]
# Epoch 11: 100%|██████████| 12396/12396 [00:02<00:00, 5446.18it/s, loss=0.192, metric=0.969]
# Epoch 12: 100%|██████████| 12396/12396 [00:02<00:00, 5556.45it/s, loss=0.178, metric=0.971]
# Epoch 13: 100%|██████████| 12396/12396 [00:02<00:00, 5314.01it/s, loss=0.167, metric=0.973]
# Epoch 14: 100%|██████████| 12396/12396 [00:02<00:00, 5761.59it/s, loss=0.156, metric=0.974]
# Epoch 15: 100%|██████████| 12396/12396 [00:01<00:00, 5929.54it/s, loss=0.147, metric=0.976]

# %%
classifier.plot()

# %% [markdown]
# # Multi-class

# %%
train_dataset = MNIST('.', train=True, download=True, transform=transform)
test_dataset = MNIST('.', train=False, transform=transform)

# %%
train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=128, shuffle=False)

# %%
neural_network = layers.NeuralNetwork([layers.Linear(784, 100),
                                       layers.ReLU(), 
                                       layers.Linear(100, 100),
                                       layers.ReLU(),
                                       layers.Linear(100, 10)])

loss = layers.NLLLoss()

# %%
classifier = wrapper.MNISTWrapper(model=neural_network,
                                  loss=loss,
                                  learning_rate=0.015,
                                  multi_class=True)

# %%
classifier.train(train_loader, test_loader)
# Out:
# Epoch 1:   0%|          | 0/60000 [00:00<?, ?it/s]/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Epoch 1: 100%|██████████| 60000/60000 [00:11<00:00, 5310.11it/s, loss=2.16, metric=0.0792]
# Epoch 2: 100%|██████████| 60000/60000 [00:10<00:00, 5543.73it/s, loss=1.99, metric=0.114]
# Epoch 3: 100%|██████████| 60000/60000 [00:10<00:00, 5478.24it/s, loss=1.86, metric=0.152]
# Epoch 4: 100%|██████████| 60000/60000 [00:10<00:00, 5529.79it/s, loss=1.58, metric=0.283]
# Epoch 5: 100%|██████████| 60000/60000 [00:10<00:00, 5631.24it/s, loss=1.27, metric=0.433]
# Epoch 6: 100%|██████████| 60000/60000 [00:10<00:00, 5489.51it/s, loss=1.09, metric=0.551]
# Epoch 7: 100%|██████████| 60000/60000 [00:09<00:00, 6283.07it/s, loss=0.867, metric=0.746]
# Epoch 8: 100%|██████████| 60000/60000 [00:12<00:00, 4745.12it/s, loss=0.602, metric=0.825]
# Epoch 9: 100%|██████████| 60000/60000 [00:11<00:00, 5316.13it/s, loss=0.438, metric=0.875]
# Epoch 10: 100%|██████████| 60000/60000 [00:11<00:00, 5292.29it/s, loss=0.335, metric=0.907]
# Epoch 11: 100%|██████████| 60000/60000 [00:10<00:00, 5589.19it/s, loss=0.264, metric=0.922]
# Epoch 12: 100%|██████████| 60000/60000 [00:11<00:00, 5414.81it/s, loss=0.231, metric=0.931]
# Epoch 13: 100%|██████████| 60000/60000 [00:10<00:00, 5525.10it/s, loss=0.209, metric=0.936]
# Epoch 14: 100%|██████████| 60000/60000 [00:11<00:00, 5426.09it/s, loss=0.191, metric=0.942]
# Epoch 15: 100%|██████████| 60000/60000 [00:10<00:00, 5466.11it/s, loss=0.177, metric=0.947]

# %%
classifier.plot()

# %% [markdown]
# # Error analysis

# %%
test_x_data = test_loader.dataset.data.view(len(test_loader.dataset), -1).numpy()
test_y_data = test_loader.dataset.targets.numpy()

# %%
test_x_prediction = classifier.predict_batch(test_x_data).argmax(1)

# %%
print(classification_report(test_y_data, test_x_prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.99      0.89       980
#            1       0.99      0.92      0.96      1135
#            2       0.84      0.95      0.89      1032
#            3       0.84      0.96      0.90      1010
#            4       0.97      0.92      0.94       982
#            5       0.96      0.85      0.90       892
#            6       0.97      0.91      0.94       958
#            7       0.99      0.76      0.86      1028
#            8       0.86      0.92      0.89       974
#            9       0.93      0.88      0.91      1009
#
#    micro avg       0.91      0.91      0.91     10000
#    macro avg       0.91      0.91      0.91     10000
# weighted avg       0.92      0.91      0.91     10000

# %%
tools.plot_confusion_matrix(test_y_data, test_x_prediction)
# Out:
# Normalized confusion matrix
